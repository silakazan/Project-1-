# %%
import sys 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime
from datetime import time

# %%
df = pd.read_csv("Desktop/turnstile_170401.csv")
df
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/25/2017
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/25/2017
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/25/2017
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/25/2017
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  03/25/2017
# ...       ...   ...       ...            ...      ...      ...         ...
# 198363  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198364  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198365  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198366  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198367  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198368 entries, 0 to 198367
# Data columns (total 11 columns):
#  #   Column                                                                Non-Null Count   Dtype
# ---  ------                                                                --------------   -----
#  0   C/A                                                                   198368 non-null  object
#  1   UNIT                                                                  198368 non-null  object
#  2   SCP                                                                   198368 non-null  object
#  3   STATION                                                               198368 non-null  object
#  4   LINENAME                                                              198368 non-null  object
#  5   DIVISION                                                              198368 non-null  object
# ...

# %%
df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  12:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6108321
# 1  REGULAR  6108343
# 2  REGULAR  6108360
# 3  REGULAR  6108462
# 4  REGULAR  6108689
# 5  REGULAR  6108983
# 6  REGULAR  6109170
# ...

# %%
df.tail(5)
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 198363  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198364  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198365  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198366  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
# 198367  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  03/31/2017
#
#             TIME     DESC  ENTRIES  \
# 198363  05:00:00  REGULAR     5554
# 198364  09:00:00  REGULAR     5554
# 198365  13:00:00  REGULAR     5554
# 198366  17:00:00  REGULAR     5554
# 198367  21:00:00  REGULAR     5554
#
#         EXITS
# 198363                                                294
# 198364                                                294
# 198365                                                294
# 198366                                                294
# ...

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %%
df.shape
# Out:
# (198368, 11)

# %%
df.sample(10, random_state=42)
# Out:
#           C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 186885  R601A  R108  02-00-01     BOROUGH HALL         2345R      IRT
# 153365  R238A  R046  02-00-04  GRD CNTRL-42 ST         4567S      IRT
# 11723    A077  R028  03-00-00        FULTON ST      ACJZ2345      BMT
# 71774    N218  R112  01-06-00       FORDHAM RD            BD      IND
# 48193    N060  R010  01-00-02  42 ST-PORT AUTH  ACENGRS1237W      IND
# 112098  PTH04  R551  00-00-04     GROVE STREET             1      PTH
# 112947  PTH05  R543  00-00-05   EXCHANGE PLACE             1      PTH
# 193017   R632  R067  00-00-02  PENNSYLVANIA AV             3      IRT
# 3235     A025  R023  01-00-01  34 ST-HERALD SQ      BDFMNQRW      BMT
# 39331    K022  R402  00-00-00       SENECA AVE             M      BMT
#
#               DATE      TIME     DESC   ENTRIES    EXITS
# 186885  03/25/2017  20:00:00  REGULAR  12657149  8055725
# 153365  03/27/2017  04:00:00  REGULAR    775572    26512
# ...

# %%
df.dtypes
# Out:
# C/A         object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES      int64
# EXITS        int64
# dtype: object

# %%
df.UNIT.max()
# Out:
# 'R572'

# %%
df.isnull().sum()
# Out:
# C/A         0
# UNIT        0
# SCP         0
# STATION     0
# LINENAME    0
# DIVISION    0
# DATE        0
# TIME        0
# DESC        0
# ENTRIES     0
# EXITS       0
# dtype: int64

# %%
df.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
df.describe()
# Out:
#             ENTRIES         EXITS
# count  1.983680e+05  1.983680e+05
# mean   3.608106e+07  2.879460e+07
# std    1.961768e+08  1.773091e+08
# min    0.000000e+00  0.000000e+00
# 25%    4.876508e+05  2.370978e+05
# 50%    2.619187e+06  1.465094e+06
# 75%    6.694274e+06  4.722654e+06
# max    2.130569e+09  2.087387e+09

# %%
df["TURNSTILE"] = df["C/A"]+"-"+df["UNIT"]+"-"+df["SCP"]

df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/26/2017  12:00:00
#
#       DESC  ENTRIES    EXITS           TURNSTILE
# 0  REGULAR  6108321  2069313  A002-R051-02-00-00
# 1  REGULAR  6108343  2069319  A002-R051-02-00-00
# ...

# %%
df['DATETIME'] = df["DATE"]+ " " + df["TIME"]
df['DATETIME'] = pd.to_datetime(df['DATETIME'], format='%m/%d/%Y %H:%M:%S')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198368 entries, 0 to 198367
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   C/A        198368 non-null  object
#  1   UNIT       198368 non-null  object
#  2   SCP        198368 non-null  object
#  3   STATION    198368 non-null  object
#  4   LINENAME   198368 non-null  object
#  5   DIVISION   198368 non-null  object
#  6   DATE       198368 non-null  object
#  7   TIME       198368 non-null  object
#  8   DESC       198368 non-null  object
#  9   ENTRIES    198368 non-null  int64
#  10  EXITS      198368 non-null  int64
#  11  TURNSTILE  198368 non-null  object
#  12  DATETIME   198368 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 21.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 198368 entries, 0 to 198367
# Data columns (total 13 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   C/A        198368 non-null  object
#  1   UNIT       198368 non-null  object
#  2   SCP        198368 non-null  object
#  3   STATION    198368 non-null  object
#  4   LINENAME   198368 non-null  object
#  5   DIVISION   198368 non-null  object
#  6   DATE       198368 non-null  object
#  7   TIME       198368 non-null  object
#  8   DESC       198368 non-null  object
#  9   ENTRIES    198368 non-null  int64
#  10  EXITS      198368 non-null  int64
#  11  TURNSTILE  198368 non-null  object
#  12  DATETIME   198368 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(10)
# memory usage: 21.2+ MB

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  03/25/2017  16:00:00
#
#       DESC  ENTRIES    EXITS           TURNSTILE            DATETIME
# 0  REGULAR  6108321  2069313  A002-R051-02-00-00 2017-03-25 00:00:00
# 1  REGULAR  6108343  2069319  A002-R051-02-00-00 2017-03-25 04:00:00
# 2  REGULAR  6108360  2069347  A002-R051-02-00-00 2017-03-25 08:00:00
# 3  REGULAR  6108462  2069456  A002-R051-02-00-00 2017-03-25 12:00:00
# 4  REGULAR  6108689  2069525  A002-R051-02-00-00 2017-03-25 16:00:00

# %%
df["NAMEOFDAY"]= df["DATETIME"].dt.day_name()

# %%
df.sample(10)
# Out:
#           C/A  UNIT       SCP          STATION LINENAME DIVISION        DATE  \
# 63577    N127  R442  00-00-00      SHEPHERD AV        C      IND  03/29/2017
# 55741    N091  R029  02-00-04      CHAMBERS ST    ACE23      IND  03/26/2017
# 197944   S102  R165  00-05-01    TOMPKINSVILLE        1      SRT  03/31/2017
# 138382   R169  R168  01-07-00            96 ST      123      IRT  03/27/2017
# 10347    A060  R001  00-00-02  WHITEHALL S-FRY      R1W      BMT  03/28/2017
# 140213   R179  R193  01-00-00           157 ST        1      IRT  03/31/2017
# 55762    N091  R029  02-00-04      CHAMBERS ST    ACE23      IND  03/29/2017
# 88130    N405  R239  00-00-00    GREENPOINT AV        G      IND  03/29/2017
# 85211   N338B  R128  00-06-00     SUTPHIN BLVD        F      IND  03/25/2017
# 86491    N342  R019  01-00-03   JAMAICA 179 ST        F      IND  03/29/2017
#
#             TIME     DESC   ENTRIES     EXITS            TURNSTILE  \
# ...

# %%
df = df[["STATION","TURNSTILE","DATE","TIME","DATETIME","NAMEOFDAY","ENTRIES","EXITS"]]
df.head(10)
# Out:
#   STATION           TURNSTILE        DATE      TIME            DATETIME  \
# 0   59 ST  A002-R051-02-00-00  03/25/2017  00:00:00 2017-03-25 00:00:00
# 1   59 ST  A002-R051-02-00-00  03/25/2017  04:00:00 2017-03-25 04:00:00
# 2   59 ST  A002-R051-02-00-00  03/25/2017  08:00:00 2017-03-25 08:00:00
# 3   59 ST  A002-R051-02-00-00  03/25/2017  12:00:00 2017-03-25 12:00:00
# 4   59 ST  A002-R051-02-00-00  03/25/2017  16:00:00 2017-03-25 16:00:00
# 5   59 ST  A002-R051-02-00-00  03/25/2017  20:00:00 2017-03-25 20:00:00
# 6   59 ST  A002-R051-02-00-00  03/26/2017  00:00:00 2017-03-26 00:00:00
# 7   59 ST  A002-R051-02-00-00  03/26/2017  04:00:00 2017-03-26 04:00:00
# 8   59 ST  A002-R051-02-00-00  03/26/2017  08:00:00 2017-03-26 08:00:00
# 9   59 ST  A002-R051-02-00-00  03/26/2017  12:00:00 2017-03-26 12:00:00
#
#   NAMEOFDAY  ENTRIES    EXITS
# 0  Saturday  6108321  2069313
# 1  Saturday  6108343  2069319
# 2  Saturday  6108360  2069347
# 3  Saturday  6108462  2069456
# ...

# %%
len(df["STATION"].unique())
# Out:
# 375

# %%
len(df["TURNSTILE"].unique())
# Out:
# 4700

# %%
print("Row count based on stations (First 10 rows)")
print(df["STATION"].value_counts().sort_values(ascending=False).head(10))
# Out:
# Row count based on stations (First 10 rows)
# 34 ST-PENN STA     4142
# FULTON ST          4019
# 23 ST              2953
# GRD CNTRL-42 ST    2883
# CANAL ST           2439
# CHAMBERS ST        2307
# 34 ST-HERALD SQ    2289
# 59 ST              2257
# 86 ST              2228
# 42 ST-PORT AUTH    2142
# Name: STATION, dtype: int64

# %%
print(df["STATION"].value_counts().sort_values(ascending=False).head(10))
# Out:
# 34 ST-PENN STA     4142
# FULTON ST          4019
# 23 ST              2953
# GRD CNTRL-42 ST    2883
# CANAL ST           2439
# CHAMBERS ST        2307
# 34 ST-HERALD SQ    2289
# 59 ST              2257
# 86 ST              2228
# 42 ST-PORT AUTH    2142
# Name: STATION, dtype: int64

# %%
ax = sns.scatterplot(x="DATE", y="ENTRIES", data=df)
plt.xticks("")
plt.show()

# %%
df_entries = df.groupby(["STATION","TURNSTILE","DATE","NAMEOFDAY"]).ENTRIES.max() - df.groupby(["STATION","TURNSTILE","DATE","NAMEOFDAY"]).ENTRIES.min()

df_exits = df.groupby(["STATION","TURNSTILE","DATE","NAMEOFDAY"]).EXITS.max() - df.groupby(["STATION","TURNSTILE","DATE","NAMEOFDAY"]).EXITS.min()

df_entries = df_entries.reset_index()

df_exits = df_exits.reset_index()

df_entries_exits = pd.merge(df_entries, df_exits, how="outer")

df_entries_exits["TRAFFIC"] = df_entries_exits["ENTRIES"] + df_entries_exits["EXITS"]

df_entries_exits.sample(10)
# Out:
#               STATION            TURNSTILE        DATE  NAMEOFDAY  ENTRIES  \
# 32487       WILSON AV   H032-R295-00-00-02  03/27/2017     Monday     1954
# 4535            28 ST   A027-R082-01-03-03  03/27/2017     Monday      964
# 22855  HOWARD BCH JFK   N182-R414-00-00-00  03/29/2017  Wednesday      854
# 4714            28 ST   R229-R143-01-00-03  03/31/2017     Friday     2104
# 2130   15 ST-PROSPECT   N542-R241-00-06-01  03/25/2017   Saturday      641
# 27077    NEWARK BM BW  PTH18-R549-01-02-03  03/31/2017     Friday      851
# 8521            51 ST   R243-R049-00-03-01  03/31/2017     Friday      945
# 27070    NEWARK BM BW  PTH18-R549-01-02-02  03/31/2017     Friday      283
# 8706            57 ST   N600-R302-00-06-02  03/29/2017  Wednesday     2702
# 9838    66 ST-LINCOLN  R160A-R164-00-00-01  03/27/2017     Monday     1698
#
#        EXITS  TRAFFIC
# 32487    851     2805
# 4535    1257     2221
# 22855     73      927
# 4714     969     3073
# 2130     417     1058
# ...

# %%
ax = sns.boxenplot(x='TRAFFIC', data=df_entries_exits,palette="bright").set(xlabel='Daily Traffic',title="Daily Traffic Based On Turnstile")

# %%
ax = sns.histplot(df_entries_exits["TRAFFIC"])
